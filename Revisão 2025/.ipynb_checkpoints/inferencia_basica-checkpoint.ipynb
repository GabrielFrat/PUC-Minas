# %%
import requests as re
import pandas as pd
from requests.auth import HTTPBasicAuth

# %%
url_get_token = 'https://finanmarket.gfreis.dev/login'

payload = {'grant_type': 'client_credentials'}
auth = ('gabrielfrat@hotmail.com', '293234619Gab!')

token_access = re.post(url_get_token, auth=auth, data=payload).json()
token_access
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyIjoiZ2FicmllbGZyYXRAaG90bWFpbC5jb20iLCJleHAiOjE3Njc4MjgxNjZ9.3Qd7wMVkj-K7tjYb-J2TGjkXT3PY9v11xeH8SKYMtmw',
#  'token_type': 'bearer'}

# %%
token = token_access['access_token']
headers = {
    'Authorization': f'Bearer {token}'
}

response = re.get('https://finanmarket.gfreis.dev/cia_aberta/itr/4170/', headers=headers)
dados = response.json()
print(dados)
# Out:
# {'4170': {'cnpj': '33592510000154', 'nome_cia': 'VALE S.A.', 'ticker': 'VALE3', 'nome': 'Vale', 'razao': 'VALE S.A.', 'abreviacao': 'VALE', 'setor': 'Materiais Básicos', 'subSetor': 'Mineração', 'segmento': 'Minerais Metálicos', 'BPA': {'2018-03-31': {'Ativo Total': 313707000.0, 'Ativo Circulante': 50650200.0, 'Caixa e Equivalentes de Caixa': 17841300.0, 'Aplicações Financeiras': 0.0, 'Aplicações Financeiras Avaliadas a Valor Justo': 0.0, 'Títulos para Negociação': 0.0, 'Títulos Disponíveis para Venda': 0.0, 'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0, 'Títulos Mantidos até o Vencimento': 0.0, 'Contas a Receber': 499254.0, 'Clientes': 0.0, 'Outras Contas a Receber': 499254.0, 'Estoques': 0.0, 'Ativos Biológicos': 0.0, 'Tributos a Recuperar': 5907420.0, 'Tributos Correntes a Recuperar': 5907420.0, 'Despesas Antecipadas': 0.0, 'Outros Ativos Circulantes': 3797630.0, 'Ativos Não-Correntes a Venda': 0.0, 'Ativos de Operações Descontinuadas': 0.0, 'Outros': 14484000.0, 'Instrumentos financeiros derivativos': 1619180.0, 'Ativo Não Circulante': 263056000.0, 'Ativo Realizável a Longo Prazo': 42150100.0, 'Tributos Diferidos': 20297100.0, 'Imposto de Renda e Contribuição Social Diferidos': 20297100.0, 'Créditos com Partes Relacionadas': 5250640.0, 'Créditos com Coligadas': 0.0, 'Créditos com Controladores': 0.0, 'Créditos com Outras Partes Relacionadas': 5250640.0, 'Outros Ativos Não Circulantes': 16103100.0, 'Investimentos': 12367700.0, 'Participações Societárias': 0.0, 'Participações em Coligadas': 0.0, 'Outras Participações Societárias': 0.0, 'Propriedades para Investimento': 0.0, 'Imobilizado': 179979000.0, 'Imobilizado em Operação': 0.0, 'Imobilizado Arrendado': 0.0, 'Imobilizado em Andamento': 0.0, 'Intangível': 28559400.0, 'Intangíveis': 0.0, 'Contrato de Concessão': 0.0, 'Goodwill': 0.0}, '2018-06-30': {'Ativo Total': 339647000.0, 'Ativo Circulante': 59639300.0, 'Caixa e Equivalentes de Caixa': 24557400.0, 'Aplicações Financeiras': 0.0, 'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado': 0.0, 'Títulos para Negociação': 0.0, 'Títulos Designados a Valor Justo': 0.0, 'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes': 0.0, 'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0, 'Contas a Receber': 593466.0, 'Clientes': 0.0, 'Outras Contas a Receber': 593466.0, 'Estoques': 0.0, 'Ativos Biológicos': 0.0, 'Tributos a Recuperar': 6478240.0, 'Tributos Correntes a Recuperar': 6478240.0, 'Despesas Antecipadas': 0.0, 'Outros Ativos Circulantes': 2835940.0, 'Ativos Não-Correntes a Venda': 0.0, 'Ativos de Operações Descontinuadas': 0.0, 'Outros': 15707400.0, 'Instrumentos financeiros derivativos': 1367770.0, 'Ativo Não Circulante': 280008000.0, 'Ativo Realizável a Longo Prazo': 48945800.0, 'Tributos Diferidos': 25199400.0, 'Imposto de Renda e Contribuição Social Diferidos': 25199400.0, 'Créditos com Partes Relacionadas': 6077760.0, 'Créditos com Coligadas': 0.0, 'Créditos com Controladores': 0.0, 'Créditos com Outras Partes Relacionadas': 6077760.0, 'Outros Ativos Não Circulantes': 17075200.0, 'Investimentos': 12440500.0, 'Participações Societárias': 0.0, 'Participações em Coligadas': 0.0, 'Participações em Controladas em Conjunto': 0.0, 'Propriedades para Investimento': 0.0, 'Imobilizado': 187816000.0, 'Imobilizado em Operação': 0.0, 'Direito de Uso em Arrendamento': 0.0, 'Imobilizado em Andamento': 0.0, 'Intangível': 30805200.0, 'Intangíveis': 0.0, 'Contrato de Concessão': 0.0, 'Goodwill': 0.0}, '2018-09-30': {'Ativo Total': 342279000.0, 'Ativo Circulante': 60585800.0, 'Caixa e Equivalentes de Caixa': 24424400.0, 'Aplicações Financeiras': 0.0, 'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado': 0.0, 'Títulos para Negociação': 0.0, 'Títulos Designados a Valor Justo': 0.0, 'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes': 0.0, 'Aplicações Financeiras Avaliadas ao Custo Amortizado': 0.0, 'Contas a Receber' ...

# %%
BPA = dados['4170']['BPA']
BPP = dados['4170']['BPP']
DRE = dados['4170']['DRE']

df = pd.DataFrame(BPA)
df_BPA = df.stack().reset_index()
df_BPA.columns = ['Nome da Conta', 'Data de Referencia', 'Valor']
df_BPA['Tipo Demonstração'] = "BPA"

df = pd.DataFrame(BPP)
df_BPP = df.stack().reset_index()
df_BPP.columns = ['Nome da Conta', 'Data de Referencia', 'Valor']
df_BPP['Tipo Demonstração'] = "BPP"

df = pd.DataFrame(DRE)
df_DRE= df.stack().reset_index()
df_DRE.columns = ['Nome da Conta', 'Data de Referencia', 'Valor']
df_DRE['Tipo Demonstração'] = "DRE"

# %%
list_dfs = [df_BPA, df_BPP, df_DRE]
df_final = pd.concat(list_dfs, ignore_index=True)
df_final.head()
# Out:
#   Nome da Conta Data de Referencia        Valor Tipo Demonstração
# 0   Ativo Total         2018-03-31  313707000.0               BPA
# 1   Ativo Total         2018-06-30  339647000.0               BPA
# 2   Ativo Total         2018-09-30  342279000.0               BPA
# 3   Ativo Total         2019-03-31  366876000.0               BPA
# 4   Ativo Total         2019-06-30  366870000.0               BPA

# %%
df_final.dtypes
# Out:
# Nome da Conta          object
# Data de Referencia     object
# Valor                 float64
# Tipo Demonstração      object
# dtype: object

# %%
list_nome_conta = df_final['Nome da Conta'].tolist()
conta = set(list_nome_conta)
conta
# Out:
# {'Adiantamento para Futuro Aumento de Capital',
#  'Ajustes Acumulados de Conversão',
#  'Ajustes de Avaliação Patrimonial',
#  'Alienação de Bônus de Subscrição',
#  'Aplicações Financeiras',
#  'Aplicações Financeiras Avaliadas a Valor Justo',
#  'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes',
#  'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado',
#  'Aplicações Financeiras Avaliadas ao Custo Amortizado',
#  'Aplicações financeiras de curto prazo',
#  'Ativo Circulante',
#  'Ativo Não Circulante',
#  'Ativo Realizável a Longo Prazo',
#  'Ativo Total',
#  'Ativos Biológicos',
#  'Ativos Não-Correntes a Venda',
#  'Ativos de Operações Descontinuadas',
#  'Atribuído a Sócios Não Controladores',
#  'Atribuído a Sócios da Empresa Controladora',
#  'Ações em Tesouraria',
#  'Caixa e Equivalentes de Caixa',
#  'Capital Social Realizado',
#  'Clientes',
#  'Contas a Receber',
#  'Contrato de Concessão',
#  'Contratos onerosos',
#  'Corrente',
#  'Créditos com Coligadas',
#  'Créditos com Controladores',
#  'Créditos com Outras Partes Relacionadas',
#  'Créditos com Partes Relacionadas',
#  'Custo de captação de recursos',
#  'Custo dos Bens e/ou Serviços Vendidos',
#  'Debentures participativas',
#  'Debêntures',
#  'Depósito judicial',
#  'Depósitos judiciais',
#  'Descaracterização das barragens',
#  'Descaracterização de barragens',
#  'Despesas Antecipadas',
#  'Despesas Financeiras',
#  'Despesas Gerais e Administrativas',
#  'Despesas com Vendas',
#  'Despesas/Receitas Operacionais',
#  'Diferido',
#  'Direito de Uso em Arrendamento',
#  'Dividendo Adicional Proposto',
#  'Dividendo Mínimo Obrigatório a Pagar',
#  'Dividendos e JCP a Pagar',
#  'Débitos com Coligadas',
#  'Débitos com Controladores',
#  'Débitos com Outras Partes Relacionadas',
#  'Em Moeda Estrangeira',
#  'Em Moeda Nacional',
#  'Empréstimos e Financiamentos',
#  'Estoques',
#  'Evento Brumadinho',
#  'Financiamento por Arrendamento',
#  'Financiamento por Arrendamento Financeiro',
#  'Fornecedores',
#  'Fornecedores Estrangeiros',
#  'Fornecedores Nacionais',
#  'Ganhos/Perdas Líquidas sobre Ativos de Operações Descontinuadas',
#  'Garantias financeiras',
#  'Goodwill',
#  'Imobilizado',
#  'Imobilizado Arrendado',
#  'Imobilizado em Andamento',
#  'Imobilizado em Operação',
#  'Imposto de Renda e Contribuição Social Diferidos',
#  'Imposto de Renda e Contribuição Social a Pagar',
#  'Imposto de Renda e Contribuição Social sobre o Lucro',
#  'Instrumentos financeiros derivativos',
#  'Intangíveis',
#  'Intangível',
#  'Investimentos',
#  'Investimentos em ações',
#  'Lucro Básico por Ação',
#  'Lucro Diluído por Ação',
#  'Lucro por Ação - (Reais / Ação)',
#  'Lucro/Prejuízo Consolidado do Período',
#  'Lucro/Prejuízo Líquido das Operações Descontinuadas',
#  'Lucros a Apropriar',
#  'Lucros e Receitas a Apropriar',
#  'Lucros/Prejuízos Acumulados',
#  'ON',
#  'Obrigações Fiscais',
#  'Obrigações Fiscais Estaduais',
#  'Obrigações Fiscais Federais',
#  'Obrigações Fiscais Municipais',
#  'Obrigações Sociais',
#  'Obrigações Sociais e Trabalhistas',
#  'Obrigações Sociais e trabalhistas',
#  'Obrigações Trabalhistas',
#  'Obrigações ambientais',
#  'Obrigações com benefícios de aposentadoria',
#  'Obrigações fiscais',
#  'Obrigações para desmobilização de ativos',
#  'Obrigações por Pagamentos Baseados em Ações',
#  'Opções Outorgadas',
#  'Outras Contas a Receber',
#  'Outras Despesas Operacionais',
#  'Outras Obrigações',
#  'Outras Participações Societárias',
#  'Outras Provisões',
#  'Outras Receitas Operacionais',
#  'Outras despesas operacionais',
#  'Outras provisões',
#  'Outros',
#  'Outros Ativos Circulantes',
#  'Outros Ativos Não Circulantes',
#  'Outros Investimentos',
#  'Outros Resultados Abrangentes',
#  'Outros resultados na participação de coligadas e joint ventures',
#  'PNA',
#  'Participação dos Acionistas Não Controladores',
#  'Participações Societárias',
#  'Participações em Coligadas',
#  'Participações em Controladas em Conjunto',
#  'Passivo Circulante',
#  'Passivo Não Circulante',
#  'Passivo Total',
#  'Passivos com Partes Relacionadas',
#  'Passivos relacionados a Brumadinho',
#  'Passivos relacionados a participação em coligadas e joint ventures',
#  'Passivos sobre Ativos Não-Correntes a Venda',
#  'Passivos sobre Ativos Não-Correntes a Venda e Descontinuados',
#  'Passivos sobre Ativos de Operações Descontinuadas',
#  'Patrimônio Líquido Consolidado',
#  'Perdas pela Não Recuperabilidade de Ativos',
#  'Perdas pela não recuperabilidade de ativos',
#  'Perdas pela não recuperalidade de ativos',
#  'Propriedades para Investimento',
#  'Provisões',
#  'Provisões Cíveis',
#  'Provisões Fiscais',
#  'Provisões Fiscais Previdenciárias Trabalhistas e Cíveis',
#  'Provisões Previdenciárias e Trabalhistas',
#  'Provisões para Benefícios a Empregados',
#  'Provisões para Garantias',
#  'Provisões para Passivos Ambientais e de Desativação',
#  'Provisões para Processos Judiciais',
#  'Provisões para Reestruturação',
#  'Provisões para processos judiciais',
#  'Recebimentos antecipados',
#  'Receita de Venda de Bens e/ou Serviços',
#  'Receitas Financeiras',
#  'Receitas a Apropriar',
#  'Redução ao valor recuperável e outros resultados na participação em coligadas e joint ventures',
#  'Reserva Especial de Ágio na Incorporação',
#  'Reserva Especial para Dividendos Não Distribuídos',
#  'Reserva Estatutária',
#  'Reserva Legal',
#  'Reserva de Incentivos Fiscais',
#  'Reserva de Lucros a Realizar',
#  'Reserva de Retenção de Lucros',
#  'Reserva para Contingências',
#  'Reserva para remuneração em ações',
#  'Reservas de Capital',
#  'Reservas de Lucros',
#  'Reservas de Reavaliação',
#  'Resultado Antes do Resultado Financeiro e dos Tributos',
#  'Resultado Antes dos Tributos sobre o Lucro',
#  'Resultado Bruto',
#  'Resultado Financeiro',
#  'Resultado Líquido das Operações Continuadas',
#  'Resultado Líquido de Operações Descontinuadas',
#  'Resultado de Equivalência Patrimonial',
#  'Resultado de alienação/baixa de participação JV/coligadas',
#  'Resultado na mensuração ou venda de ativos não circulantes',
#  'Subvenções de Investimento a Apropriar',
#  'Transações de streaming',
#  'Tributos Correntes a Recuperar',
#  'Tributos Diferidos',
#  'Tributos a Recuperar',
#  'Títulos Designados a Valor Justo',
#  'Títulos Disponíveis para Venda',
#  'Títulos Mantidos até o Vencimento',
#  'Títulos para Negociação',
#  'provisões para processos judiciais',
#  'Ágio na Emissão de Ações'}

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

nome_da_conta_alvo = 'Lucro/Prejuízo Consolidado do Período'

df_plot = df_final[df_final['Nome da Conta'] == nome_da_conta_alvo].copy()
df_plot['Data de Referencia'] = pd.to_datetime(df_plot['Data de Referencia'])
df_plot = df_plot.sort_values('Data de Referencia')
df_plot['Valor_Bilhoes'] = df_plot['Valor'] / 1_000_000

plt.figure(figsize=(12, 6))

plt.plot(df_plot['Data de Referencia'], df_plot['Valor_Bilhoes'], 
         marker='o', linestyle='-', linewidth=2, color='#005b96')

plt.axhline(0, color='red', linestyle='--', linewidth=1, alpha=0.7)

plt.fill_between(df_plot['Data de Referencia'], df_plot['Valor_Bilhoes'], 0, 
                 where=(df_plot['Valor_Bilhoes'] >= 0), color='green', alpha=0.1)
plt.fill_between(df_plot['Data de Referencia'], df_plot['Valor_Bilhoes'], 0, 
                 where=(df_plot['Valor_Bilhoes'] < 0), color='red', alpha=0.1)


plt.title(f'Evolução: {nome_da_conta_alvo}', fontsize=14)
plt.ylabel('R$ Bilhões', fontsize=12)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gcf().autofmt_xdate()

for x, y in zip(df_plot['Data de Referencia'], df_plot['Valor_Bilhoes']):
    label = f"{y:.1f}B"
    plt.annotate(label, (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.grid(True, linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# varificar medidas de variabilidade e tendencia central sobre o Lucro/Prejuízo Consolidado do Período

df_lucro_prejuizo = df_final.loc[df_final['Nome da Conta'] == 'Lucro/Prejuízo Consolidado do Período']
df_lucro_prejuizo

print('Média dos dados:', df_lucro_prejuizo['Valor'].mean())
print('Mediana dos dados:', df_lucro_prejuizo['Valor'].median())
print('Desvio Padrão dos dados:', df_lucro_prejuizo['Valor'].std())
print('Variância dos dados:', df_lucro_prejuizo['Valor'].var())

cv = (df_lucro_prejuizo['Valor'].std() / df_lucro_prejuizo['Valor'].mean()) * 100
print(f"Coeficiente de Variação dos dados: {cv:.2f}%")

q1 = df_lucro_prejuizo['Valor'].quantile(0.25)
q2 = df_lucro_prejuizo['Valor'].quantile(0.50)
q3 = df_lucro_prejuizo['Valor'].quantile(0.75)

print(f"Quartis dos dados: Q1={q1}, Q2={q2}, Q3={q3}")
# Out:
# Média dos dados: 12528965.047619049
# Mediana dos dados: 9734000.0
# Desvio Padrão dos dados: 11796519.001692982
# Variância dos dados: 139157860557303.58
# Coeficiente de Variação dos dados: 94.15%
# Quartis dos dados: Q1=4877110.0, Q2=9734000.0, Q3=20574200.0

# %%
 df_final.describe
# Out:
# <bound method NDFrame.describe of                      Nome da Conta Data de Referencia        Valor  \
# 0                      Ativo Total         2018-03-31  313707000.0
# 1                      Ativo Total         2018-06-30  339647000.0
# 2                      Ativo Total         2018-09-30  342279000.0
# 3                      Ativo Total         2019-03-31  366876000.0
# 4                      Ativo Total         2019-06-30  366870000.0
# ...                            ...                ...          ...
# 3368  Outras despesas operacionais         2023-06-30   -1893000.0
# 3369  Outras despesas operacionais         2023-09-30   -2472000.0
# 3370  Outras despesas operacionais         2024-03-31   -2266000.0
# 3371  Outras despesas operacionais         2024-06-30   -2966000.0
# 3372  Outras despesas operacionais         2024-09-30   -3334000.0
#
#      Tipo Demonstração
# 0                  BPA
# 1                  BPA
# 2                  BPA
# 3                  BPA
# 4                  BPA
# ...                ...
# 3368               DRE
# 3369               DRE
# 3370               DRE
# 3371               DRE
# 3372               DRE
#
# [3373 rows x 4 columns]>

# %%
df_plot = df_final[df_final['Nome da Conta'] == 'Ativo Total'].copy()
df_plot
plt.figure(figsize=(12, 6))
df_plot['Valor_Milhoes'] = df_plot['Ativo Total'] / 1_000_000
plt.plot(df_plot['Data de Referencia'], df_plot['Valor_Milhoes'], marker='o', color='blue', linestyle='solid')
plt.title('Evolução do Ativo Total da Vale')
plt.xticks(rotation=30)
plt.ylabel('Ativo Total em Bilhões (R$)')
plt.show()
